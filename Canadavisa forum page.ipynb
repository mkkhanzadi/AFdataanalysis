# %%
import requests
import bs4
from bs4 import BeautifulSoup as bs
import csv
import re
import numpy as np
import pandas as pd
import nltk

# %%
#defining the url and using the ureq to read the website in html. This can be checked by print(canadavisa)

# %%
canadavisa_url = 'https://www.canadavisa.com/canada-immigration-discussion-board/'
canadavisa = requests.get(canadavisa_url).text

# %%
#all topics are in tag 'h3' - using bs to find all data in h3

# %%
soup = bs(canadavisa, 'html.parser')

topics = soup.find_all('h3', {'class':'nodeTitle'})
titles = list(map(lambda h: h.text.strip(), topics))
topic_titles_and_links = dict(map(lambda h: (h.text.strip(), h.find('a') ['href']), topics))
#print(topic_titles_and_links)

# %%
with open('titles_and_links.csv', mode='w') as csv_file:
    fieldnames = ['title', 'link']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for key, value in titles_and_links.items():
        writer.writerow({'title': key, 'link': value})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-84c4d7fa9d8c> in <module>()
#       4
#       5     writer.writeheader()
# ----> 6     for key, value in titles_and_links.items():
#       7         writer.writerow({'title': key, 'link': value})
#
# NameError: name 'titles_and_links' is not defined

# %%
message_ids = list()
links = list()
date_contents = list()
username_contents = list()
message_contents = list()
countries = list()
likes = list()
topic_contents = list()
thread_contents = list()
counter = 0
thread_counter = 0
thread_page_counter = 0


for key, value in topic_titles_and_links.items():
    counter = counter + 1
    if counter == 1:
        print('inside loop', key, value)
        continue
# For debugging only - COMMENT OUT LATER
    if counter > 2:
        break
    topic_url = canadavisa_url + value 
    topic_title = key

    print("Processing ", topic_title)
    try:
        topic_content = bs(requests.get(topic_url).text, 'html.parser')
        tc_last_page = int(re.search('Page \d* of (\d*)', topic_content.select('span.pageNavHeader')[0].text).group(1))
    except Exception as i:
        print(i)
    
    for x in range(1, tc_last_page + 1):
        if x > 3:
            break
        topic_url = canadavisa_url + value
        if x > 1:
            topic_url = topic_url + 'page-'+ str(x)
        print(topic_url)
        topic_content = bs(requests.get(topic_url).text, 'html.parser')
        threads = topic_content.find_all('h3', {'class':'title'})
        thread_titles_and_links = dict(map(lambda subtopic: (subtopic.text.strip(), subtopic.find('a') ['href']), threads))
        thread_counter = 0
        print (thread_titles_and_links)
        
        for st_key, st_value in thread_titles_and_links.items():
            thread_counter = thread_counter + 1
            if thread_counter > 3:
                break
            thread_url = canadavisa_url + st_value
            thread_title = st_key
            thread_content = bs(requests.get(thread_url).text, 'html.parser')

            last_page = 1
            try:

                last_page = int(re.search('Page \d* of (\d*)', thread_content.select('span.pageNavHeader')[0].text).group(1))
            except Exception as e: 
                print(e)
            for x in range(1, last_page + 1):
                if x > 3:
                    break

                thread_url = canadavisa_url + st_value
                if x > 1:
                    thread_url = thread_url + 'page-' + str(x)
                print(thread_url)
                thread_content = bs(requests.get(thread_url).text, 'html.parser')
                messages = thread_content.select('div.messageContent')
                m_ids = thread_content.select('li.message')
                message_urls = thread_content.select('div.uix_message a.datePermalink')
                message_likes = thread_content.select('div.uix_message div.uix_userTextInner > dl:nth-of-type(2) > dd')
                message_dates = thread_content.select('span.DateTime')
                message_usernames = thread_content.select('a.username')
                message_list = list(map(lambda message: (message.find('blockquote').decode_contents().strip()), messages))
                usernames_list = list(map(lambda a: a.text.strip(), message_usernames))
                for idx, m in enumerate(message_list):
                    message_id = ""
                    try:
                        message_id = re.search('post-(\d*)', m_ids[idx]['id']).group(1)
                    except IndexError:
                        message_id = ""
                    message_ids.append(message_id)
                    link = ""
                    try:
                        link = 'https://www.canadavisa.com/' + message_urls[idx]['href']
                    except IndexError:
                        link = ""
                    links.append(link)
                    message_date = ""
                    try:
                        message_date = message_dates[idx]['title']
                    except IndexError:
                        message_date = ""
                    date_contents.append(message_date)
                    message_username = ""
                    try:
                        message_username = usernames_list[idx]
                    except IndexError:
                        message_username = ""
                    username_contents.append(message_username)
                    
                    message_contents.append(m.replace('\n', ""))

                    countries.append("NA")
                    like = ""
                    try:
                        like = message_likes[idx].text
                    except IndexError:
                        like = ""
                    likes.append(like)
                    topic_contents.append(topic_title)
                    thread_contents.append(thread_title)
# Out:
# inside loop Immigration to Canada .#immigration-to-canada.9
# Processing  Express Entry / Expression of Interest
# https://www.canadavisa.com/canada-immigration-discussion-board/forums/express-entry-expression-of-interest.54/
# {'Express Entry Step by step instructions.': 'threads/express-entry-step-by-step-instructions.273928/', 'Express Entry in a nutshell': 'threads/express-entry-in-a-nutshell.394158/', 'SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EXPRESS ENTRY PNP STREAMS': 'threads/summary-of-eligibility-requirements-for-all-express-entry-pnp-streams.432937/', '>>>>JANUARY 2019 AoR<<<< Join here': 'threads/january-2019-aor-join-here.603394/', '>>>>>>>>AUGUST 2019 AOR<<<<<<<-----Join here': 'threads/august-2019-aor-join-here.646154/', 'If I decline an ITA, will I be reconsidered in the next round of invitations ?': 'threads/if-i-decline-an-ita-will-i-be-reconsidered-in-the-next-round-of-invitations.649942/', 'Thank you  >>>>>>>>>  Legalfalcon  <<<<<<<<<<<': 'threads/thank-you-legalfalcon.408185/', 'December 2018 AOR - join here': 'threads/december-2018-aor-join-here.598089/', 'I have an ITA, but forgot to put previous jobs experience.': 'threads/i-have-an-ita-but-forgot-to-put-previous-jobs-experience.649910/', "Sydney, Nova Scotia Visa Office - Let's connect here!": 'threads/sydney-nova-scotia-visa-office-lets-connect-here.477062/', 'ITA August 20th 2019 124': 'threads/ita-august-20th-2019-124.649870/', 'Is address proof needed for current address, if its different from permanent address': 'threads/is-address-proof-needed-for-current-address-if-its-different-from-permanent-address.649941/', 'Two or more certificates, diplomas, or degrees. HELP?': 'threads/two-or-more-certificates-diplomas-or-degrees-help.455045/', 'October 2018 AOR - join here': 'threads/october-2018-aor-join-here.587953/', 'no surname but express entry online profile wrote it to be mandatory field': 'threads/no-surname-but-express-entry-online-profile-wrote-it-to-be-mandatory-field.263725/', 'Work Permit': 'threads/work-permit.649937/', 'Should I raise CSE for a new Photograph?': 'threads/should-i-raise-cse-for-a-new-photograph.649846/', 'Ray of Hope - 125th Draw': 'threads/ray-of-hope-125th-draw.649797/', '>>>>>>>>July 2019 AOR<<<<<<<-----Join here': 'threads/july-2019-aor-join-here.640012/', 'Landing Appointment - how to prove last entry to Canada if I never got a stamp?': 'threads/landing-appointment-how-to-prove-last-entry-to-canada-if-i-never-got-a-stamp.649933/', 'Proof of funds - Queries': 'threads/proof-of-funds-queries.649836/', 'Express entry': 'threads/express-entry.649930/', "Anyone's application got processed in Edmonton visa office?": 'threads/anyones-application-got-processed-in-edmonton-visa-office.577626/', 'GCMS says Eligibility not met.. BUt Application not yet rejected!!': 'threads/gcms-says-eligibility-not-met-but-application-not-yet-rejected.615390/', 'Newborn photos after PPR mail': 'threads/newborn-photos-after-ppr-mail.649883/', 'IQAS ECA timeline tracking': 'threads/iqas-eca-timeline-tracking.490054/', 'Complete/full academic years ?': 'threads/complete-full-academic-years.649895/', 'Discussion groups for Pre-ITA, post-ITA, PPR & Landing, Ontario on Telegram': 'threads/discussion-groups-for-pre-ita-post-ita-ppr-landing-ontario-on-telegram.529196/', 'Ray of Hope - 124th Draw': 'threads/ray-of-hope-124th-draw.648186/', 'Hi friends, i need help with job responsibilities of NOC 2174': 'threads/hi-friends-i-need-help-with-job-responsibilities-of-noc-2174.649789/', 'I need help figuring out my country of study!.': 'threads/i-need-help-figuring-out-my-country-of-study.542110/', 'Post ITA - Urgent help!': 'threads/post-ita-urgent-help.643400/', 'How can I get refugee visa': 'threads/how-can-i-get-refugee-visa.649926/', 'Passport to CPC Ottawa August 2019': 'threads/passport-to-cpc-ottawa-august-2019.648653/', 'October 29 2018 ITA': 'threads/october-29-2018-ita.625938/', 'Refund from WES?': 'threads/refund-from-wes.546259/', 'September 2018 AOR - join here': 'threads/september-2018-aor-join-here.581191/', 'To know the company': 'threads/to-know-the-company.645843/', 'Bachelor of Law (LLB) ECA': 'threads/bachelor-of-law-llb-eca.556498/', 'March 2018 AOR - join h ...
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/express-entry-step-by-step-instructions.273928/
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/express-entry-step-by-step-instructions.273928/page-2
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/express-entry-step-by-step-instructions.273928/page-3
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/express-entry-in-a-nutshell.394158/
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/express-entry-in-a-nutshell.394158/page-2
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/express-entry-in-a-nutshell.394158/page-3
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/summary-of-eligibility-requirements-for-all-express-entry-pnp-streams.432937/
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/summary-of-eligibility-requirements-for-all-express-entry-pnp-streams.432937/page-2
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/summary-of-eligibility-requirements-for-all-express-entry-pnp-streams.432937/page-3
# https://www.canadavisa.com/canada-immigration-discussion-board/forums/express-entry-expression-of-interest.54/page-2
# {'May 2018 AOR - join here': 'threads/may-2018-aor-join-here.557393/', 'Canadian work permit from Doha Qatar ??': 'threads/canadian-work-permit-from-doha-qatar.636742/', 'How Much Time It Takes From Passport to Visa Stamped via VFS': 'threads/how-much-time-it-takes-from-passport-to-visa-stamped-via-vfs.485840/', 'Ottawa Case Processing Centre applicants - Lets connect here.': 'threads/ottawa-case-processing-centre-applicants-lets-connect-here.538825/', 'Getting married after receiving COPR': 'threads/getting-married-after-receiving-copr.575078/', 'Working remotely for a Quebec-based company?': 'threads/working-remotely-for-a-quebec-based-company.523349/', 'Whatsapp Group for Tamil People': 'threads/whatsapp-group-for-tamil-people.286555/', 'Need urgent help. Do we need divorce certificate.': 'threads/need-urgent-help-do-we-need-divorce-certificate.514417/', '>>>>>>>>June 2019 AOR<<<<<<<Join here': 'threads/june-2019-aor-join-here.634445/', 'URGENT: NOC help!!!': 'threads/urgent-noc-help.649829/', 'Application rejected for being incomplete...': 'threads/application-rejected-for-being-incomplete.506694/', 'UAE Police certificate (PCC) from Pakistan': 'threads/uae-police-certificate-pcc-from-pakistan.634680/', 'FSW - Work Experience (Part Time) During Full Time Studies': 'threads/fsw-work-experience-part-time-during-full-time-studies.649826/', 'CRS 454 any hope ?': 'threads/crs-454-any-hope.649575/', 'Diploma Without Transcripts for Express Entry': 'threads/diploma-without-transcripts-for-express-entry.649708/', 'ICES (BCIT) Timeline': 'threads/ices-bcit-timeline.621078/', 'This thread is inactive': 'threads/this-thread-is-inactive.649808/', 'Work experience through temp agency': 'threads/work-experience-through-temp-agency.391649/', 'Late passport after ppr': 'threads/late-passport-after-ppr.649705/', 'ECA from University of Toronto (CES)': 'threads/eca-from-university-of-toronto-ces.618152/', 'Proof of fund': 'threads/proof-of-fund.560934/', 'Medical Surveillance': 'threads/medical-surveillance.549286/', 'Spouse exclusion after passport request letter': 'threads/spouse-exclusion-after-passport-request-letter.624349/', 'COPR expired when received': 'threads/copr-expired-when-received.649802/', 'January 2019 AOR - Temporary resident Visa applicant': 'threads/january-2019-aor-temporary-resident-visa-applicant.635428/', 'Counterfoil Document Status': 'threads/counterfoil-document-status.566845/', 'Anticipated Marriage after Ontario PNP': 'threads/anticipated-marriage-after-ontario-pnp.397216/', 'PCC and Funds requirement for applicant in living in Canada': 'threads/pcc-and-funds-requirement-for-applicant-in-living-in-canada.649806/', 'Proof of Funds/ settlement funds': 'threads/proof-of-funds-settlement-funds.638387/', 'Work Experience': 'threads/work-experience.649804/', 'COPR Question': 'threads/copr-question.649799/', 'London office - Interview experience and questions for others': 'threads/london-office-interview-experience-and-questions-for-others.391206/', 'File at VO CIO Sydney assigned to CB01126, let’s connect here!': 'threads/file-at-vo-cio-sydney-assigned-to-cb01126-let%E2%80%99s-connect-here.623754/', 'July 2018 AOR - join here': 'threads/july-2018-aor-join-here.569196/', 'Police Clearance Certificate(PCC) - India atlanta consulate': 'threads/police-clearance-certificate-pcc-india-atlanta-consulate.649795/', 'IMP!!! Does WES consider MBA in Distance from IMT GHAZIABAD': 'threads/imp-does-wes-consider-mba-in-distance-from-imt-ghaziabad.461759/', 'Crs score 445 to 450 any chances this year or by 2020?': 'threads/crs-score-445-to-450-any-chances-this-year-or-by-2020.649777/', 'I am stuck at Eligibility Review Required.. Need Help': 'threads/i-am-stuck-at-eligibility-review-required-need-help.572282/', 'Ray of Hope - 123rd Draw': 'threads/ray-of-hope-123rd-draw.644723/', 'WES Report': 'threads/wes-report.508684/', 'date mistake in translated document': 'threads/date-mistake-in-translated-document.649781/', 'Big confusion on ...
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/may-2018-aor-join-here.557393/
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/may-2018-aor-join-here.557393/page-2
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/may-2018-aor-join-here.557393/page-3
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/canadian-work-permit-from-doha-qatar.636742/
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/canadian-work-permit-from-doha-qatar.636742/page-2
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/canadian-work-permit-from-doha-qatar.636742/page-3
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/how-much-time-it-takes-from-passport-to-visa-stamped-via-vfs.485840/
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/how-much-time-it-takes-from-passport-to-visa-stamped-via-vfs.485840/page-2
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/how-much-time-it-takes-from-passport-to-visa-stamped-via-vfs.485840/page-3
# https://www.canadavisa.com/canada-immigration-discussion-board/forums/express-entry-expression-of-interest.54/page-3
# {'Is MS from BITS Pilani (WILP) considered as Masters in Canada by WES?': 'threads/is-ms-from-bits-pilani-wilp-considered-as-masters-in-canada-by-wes.532782/', 'Misdemeanor case in usa': 'threads/misdemeanor-case-in-usa.614129/', 'Proof of Funds: Format of Gift Deed, Affidavit and LOE': 'threads/proof-of-funds-format-of-gift-deed-affidavit-and-loe.487054/', 'Canadian spouse. Not accompanying.': 'threads/canadian-spouse-not-accompanying.649535/', 'Degree requirement for skilled worker visa': 'threads/degree-requirement-for-skilled-worker-visa.649677/', 'Our Thousand Islands Lansdowne landing experience': 'threads/our-thousand-islands-lansdowne-landing-experience.649319/', 'NOC 4011 or 4021 Confusion': 'threads/noc-4011-or-4021-confusion.649667/', 'No option for 3-4 years of work experience while applying for EE Profile': 'threads/no-option-for-3-4-years-of-work-experience-while-applying-for-ee-profile.649586/', "Pakistani Applicants for Express Entry, Let's Network Here": 'threads/pakistani-applicants-for-express-entry-lets-network-here.259690/', 'PR with express entry': 'threads/pr-with-express-entry.649654/', 'ECA Evaluation for PGDM from WES and ICES': 'threads/eca-evaluation-for-pgdm-from-wes-and-ices.608723/', 'Dealing with Post ITA Pregnancy': 'threads/dealing-with-post-ita-pregnancy.529951/', 'Martial Status can I get married while  OINP in process': 'threads/martial-status-can-i-get-married-while-oinp-in-process.458810/', 'FRRO PCC -India': 'threads/frro-pcc-india.640423/', 'LLB evaluation question': 'threads/llb-evaluation-question.464132/', 'COPR Error!': 'threads/copr-error.631158/', 'CRS score': 'threads/crs-score.649612/', 'Duplicate ECA?': 'threads/duplicate-eca.649617/', 'Huge problem with OINP e filling portal (education part)': 'threads/huge-problem-with-oinp-e-filling-portal-education-part.649602/', 'Ontario Nomination Application Payment error': 'threads/ontario-nomination-application-payment-error.649611/', 'Soft landing experience on August 02 at Windsor, ON. Express entry.': 'threads/soft-landing-experience-on-august-02-at-windsor-on-express-entry.649610/', 'ECA Report: Two or more diploma or degree option': 'threads/eca-report-two-or-more-diploma-or-degree-option.401247/', 'NOC code for Bid Manager (Industry - Information Technology)': 'threads/noc-code-for-bid-manager-industry-information-technology.530771/', 'The immediate supervisor': 'threads/the-immediate-supervisor.280368/', 'June/July 2019: Anyone who submitted the passport to CPC Ottawa': 'threads/june-july-2019-anyone-who-submitted-the-passport-to-cpc-ottawa.642937/', 'CIO Sydney': 'threads/cio-sydney.508298/', 'LONDON Visa Office Applicants....Lets connect here': 'threads/london-visa-office-applicants-lets-connect-here.406986/', 'Job Bank account and Express Entry profile are connected or not?': 'threads/job-bank-account-and-express-entry-profile-are-connected-or-not.649588/', 'Applications "under processing" for more than 15 months and not finalized': 'threads/applications-under-processing-for-more-than-15-months-and-not-finalized.489345/', 'June 2018 AOR - join here': 'threads/june-2018-aor-join-here.563316/', 'LMIA Exempt job': 'threads/lmia-exempt-job.649580/', 'Legally Separated status in profile and documents required': 'threads/legally-separated-status-in-profile-and-documents-required.649581/', 'Computer/Systems Engineer with non-IT/Computers degree': 'threads/computer-systems-engineer-with-non-it-computers-degree.649553/', 'IQAS': 'threads/iqas.646350/', 'Applying for PR card and leaving Canada for few months': 'threads/applying-for-pr-card-and-leaving-canada-for-few-months.649569/', 'Work experience': 'threads/work-experience.649554/', 'Sending Document to WES': 'threads/sending-document-to-wes.649390/', "Selected NOC 1114, need confirmation if it's correct!": 'threads/selected-noc-1114-need-confirmation-if-its-correct.649358/', 'Passport stuck at a Fedex location, need your inputs.': 'threads/passport-stuck-at-a-fedex-location-need-yo ...
# list index out of range
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/is-ms-from-bits-pilani-wilp-considered-as-masters-in-canada-by-wes.532782/
# list index out of range
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/misdemeanor-case-in-usa.614129/
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/proof-of-funds-format-of-gift-deed-affidavit-and-loe.487054/
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/proof-of-funds-format-of-gift-deed-affidavit-and-loe.487054/page-2
# https://www.canadavisa.com/canada-immigration-discussion-board/threads/proof-of-funds-format-of-gift-deed-affidavit-and-loe.487054/page-3

# %%
# Create empty frame
#base_data_frame = pd.DataFrame({ "ID": message_ids, "Link": links, "Date": date_contents, "Username": username_contents, "Message": message_contents, "Country": [], "Like": [], "Topic": topic_contents, "Thread": thread_contents})
base_data_frame = pd.DataFrame({ "ID": message_ids, 
                                "Link": links, 
                                "Date": date_contents,
                                "Username": username_contents, 
                                "Message": message_contents, 
                                "Country": countries, 
                                "Like": likes, 
                                "Topic": topic_contents, 
                                "Thread": thread_contents})
print('Finished')
# Out:
# Finished

# %%
len(base_data_frame)
# Out:
# 320

# %%
# from https://github.com/pandas-dev/pandas/issues/22610
import csv
with open("can-forum.csv", "w", errors='surrogatepass') as _file:
    writer = csv.writer(_file)
    #writer.writerow(row)
    writer.writerow(base_data_frame.columns.values)
    for index, row in base_data_frame.iterrows():
        writer.writerow(row)

# %%
base_data_frame.iloc[0:100]
# Out:
#          ID                                               Link  \
# 0   4108404  https://www.canadavisa.com/threads/express-ent...
# 1   4108507  https://www.canadavisa.com/threads/express-ent...
# 2   4108562  https://www.canadavisa.com/threads/express-ent...
# 3   4109447  https://www.canadavisa.com/threads/express-ent...
# 4   4109491  https://www.canadavisa.com/threads/express-ent...
# 5   4109660  https://www.canadavisa.com/threads/express-ent...
# 6   4109690  https://www.canadavisa.com/threads/express-ent...
# 7   4109714  https://www.canadavisa.com/threads/express-ent...
# 8   4110181  https://www.canadavisa.com/threads/express-ent...
# 9   4112140  https://www.canadavisa.com/threads/express-ent...
# 10  4113872  https://www.canadavisa.com/threads/express-ent...
# 11  4113960  https://www.canadavisa.com/threads/express-ent...
# 12  4113992  https://www.canadavisa.com/threads/express-ent...
# 13  4114764  https://www.canadavisa.com/threads/express-ent...
# 14  4114876  https://www.canadavisa.com/threads/express-ent...
# 15  4115059  https://www.canadavisa.com/threads/express-ent...
# 16  4115147  https://www.canadavisa.com/threads/express-ent...
# 17  4115897  https://www.canadavisa.com/threads/express-ent...
# 18  4116177  https://www.canadavisa.com/threads/express-ent...
# 19  4116187  https://www.canadavisa.com/threads/express-ent...
# 20  4116714  https://www.canadavisa.com/threads/express-ent...
# 21  4118191  https://www.canadavisa.com/threads/express-ent...
# 22  4118766  https://www.canadavisa.com/threads/express-ent...
# 23  4118958  https://www.canadavisa.com/threads/express-ent...
# 24  4119344  https://www.canadavisa.com/threads/express-ent...
# 25  4119813  https://www.canadavisa.com/threads/express-ent...
# 26  4120453  https://www.canadavisa.com/threads/express-ent...
<div class="bbCodeBlock bbCodeQuote" data-auth...      NA      4
# 11  You must declare your legal status in the docu...      NA    505
# 12  Perhaps I am misunderstanding your question?  ...      NA    505
# 13  Hey guys in my Application/profile details for...      NA      3
# 14  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA      9
# 15  Do you know what postdoctoral fellow already w...      NA      1
# 16  Hi YamPower ,<br/><br/>Amazing explanation , I...      NA      2
# 17  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA     67
# 18  Hi Mate,<br/><br/>I am also in same situation,...      NA      3
# 19  Hi Mate,<br/>I have 1 more question - <br/><br...      NA      3
# 20  Hi there, <br/>my younger brother is a permane...      NA      0
# 21  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA    510
# 22  I had a query regarding completing my EE profi...      NA      1
# 23  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA      5
# 24  Thank you for your guidance  <img alt=";)" cla...      NA      0
# 25  very good summary with appropriate ref.<br/>th...      NA      4
# 26  Hello YamPower,<br/><br/>Thanks for posting th...      NA      2
# 27  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA      9
# 28  Do I need to pay 550$ right after I submit my ...      NA      2
# 29  I have one question: <br/>Will CIC require a p...      NA      1
# ..                                                ...     ...    ...
# 70  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA     73
# 71  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA      1
# 72  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA  1,120
# 73  See the reply in red colour<br/><br/><div clas...      NA     73
# 74  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA      1
# 75  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA  1,120
# 76  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA      1
# 77  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA  1,120
# 78  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA      1
# 79  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA  1,120
# 80  Excellent blog Rajkamalmohanram, you are anoth...      NA      1
# 81  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA  1,120
# 82  Hi,<br/><br/>Very useful post. Thank you so mu...      NA      0
# 83  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA  1,120
# 84  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA  1,353
# 85  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA    123
# 86  <div class="bbCodeBlock bbCodeQuote"><aside><b...      NA    123
# 87  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA  1,120
# 88  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA  1,120
# 89  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA      0
# 90  Hi all, <br/><br/>Isn't it a big problem for b...      NA    123
# 91  Great effort <br/><br/>Thanks  <img alt=":)" c...      NA     51
# 92  An excellent work  8) 8)<br/><br/> Thanks for ...      NA      0
# 93  How I wish this thread gets pinned so everyone...      NA     26
# 94  Hey THATS SIMPLY AWESOME!<br/><br/>Can we use ...      NA  1,631
# 95  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA    123
# 96  Great Work +1\t\t\t\t\t\t<div class="messageTe...      NA     94
# 97  Excellent!!\t\t\t\t\t\t<div class="messageText...      NA     16
# 98  excellent mate. Thanks a lot\t\t\t\t\t\t<div c...      NA      1
# 99  <div class="bbCodeBlock bbCodeQuote" data-auth...      NA    123
#
#                                      Topic  \
# 0   Express Entry / Expression of Interest
# 1   Express Entry / Expression of Interest
# 2   Express Entry / Expression of Interest
# 3   Express Entry / Expression of Interest
# 4   Express Entry / Expression of Interest
# 5   Express Entry / Expression of Interest
# 6   Express Entry / Expression of Interest
# 7   Express Entry / Expression of Interest
# 8   Express Entry / Expression of Interest
# 9   Express Entry / Expression of Interest
# 10  Express Entry / Expression of Interest
# 11  Express Entry / Expression of Interest
# 12  Express Entry / Expression of Interest
# 13  Express Entry / Expression of Interest
# 14  Express Entry / Expression of Interest
# 15  Express Entry / Expression of Interest
# 16  Express Entry / Expression of Interest
# 17  Express Entry / Expression of Interest
# 18  Express Entry / Expression of Interest
# 19  Express Entry / Expression of Interest
# 20  Express Entry / Expression of Interest
# 21  Express Entry / Expression of Interest
# 22  Express Entry / Expression of Interest
# 23  Express Entry / Expression of Interest
# 24  Express Entry / Expression of Interest
# 25  Express Entry / Expression of Interest
# 26  Express Entry / Expression of Interest
# 27  Express Entry / Expression of Interest
# 28  Express Entry / Expression of Interest
# 29  Express Entry / Expression of Interest
# ..                                     ...
# 70  Express Entry / Expression of Interest
# 71  Express Entry / Expression of Interest
# 72  Express Entry / Expression of Interest
# 73  Express Entry / Expression of Interest
# 74  Express Entry / Expression of Interest
# 75  Express Entry / Expression of Interest
# 76  Express Entry / Expression of Interest
# 77  Express Entry / Expression of Interest
# 78  Express Entry / Expression of Interest
# 79  Express Entry / Expression of Interest
# 80  Express Entry / Expression of Interest
# 81  Express Entry / Expression of Interest
# 82  Express Entry / Expression of Interest
# 83  Express Entry / Expression of Interest
# 84  Express Entry / Expression of Interest
# 85  Express Entry / Expression of Interest
# 86  Express Entry / Expression of Interest
# 87  Express Entry / Expression of Interest
# 88  Express Entry / Expression of Interest
# 89  Express Entry / Expression of Interest
# 90  Express Entry / Expression of Interest
# 91  Express Entry / Expression of Interest
# 92  Express Entry / Expression of Interest
# 93  Express Entry / Expression of Interest
# 94  Express Entry / Expression of Interest
# 95  Express Entry / Expression of Interest
# 96  Express Entry / Expression of Interest
# 97  Express Entry / Expression of Interest
# 98  Express Entry / Expression of Interest
# 99  Express Entry / Expression of Interest
#
#                                                Thread
# 0            Express Entry Step by step instructions.
# 1            Express Entry Step by step instructions.
# 2            Express Entry Step by step instructions.
# 3            Express Entry Step by step instructions.
# 4            Express Entry Step by step instructions.
# 5            Express Entry Step by step instructions.
# 6            Express Entry Step by step instructions.
# 7            Express Entry Step by step instructions.
# 8            Express Entry Step by step instructions.
# 9            Express Entry Step by step instructions.
# 10           Express Entry Step by step instructions.
# 11           Express Entry Step by step instructions.
# 12           Express Entry Step by step instructions.
# 13           Express Entry Step by step instructions.
# 14           Express Entry Step by step instructions.
# 15           Express Entry Step by step instructions.
# 16           Express Entry Step by step instructions.
# 17           Express Entry Step by step instructions.
# 18           Express Entry Step by step instructions.
# 19           Express Entry Step by step instructions.
# 20           Express Entry Step by step instructions.
# 21           Express Entry Step by step instructions.
# 22           Express Entry Step by step instructions.
# 23           Express Entry Step by step instructions.
# 24           Express Entry Step by step instructions.
# 25           Express Entry Step by step instructions.
# 26           Express Entry Step by step instructions.
# 27           Express Entry Step by step instructions.
# 28           Express Entry Step by step instructions.
# 29           Express Entry Step by step instructions.
# ..                                                ...
# 70                        Express Entry in a nutshell
# 71                        Express Entry in a nutshell
# 72                        Express Entry in a nutshell
# 73                        Express Entry in a nutshell
# 74                        Express Entry in a nutshell
# 75                        Express Entry in a nutshell
# 76                        Express Entry in a nutshell
# 77                        Express Entry in a nutshell
# 78                        Express Entry in a nutshell
# 79                        Express Entry in a nutshell
# 80                        Express Entry in a nutshell
# 81                        Express Entry in a nutshell
# 82                        Express Entry in a nutshell
# 83                        Express Entry in a nutshell
# 84                        Express Entry in a nutshell
# 85                        Express Entry in a nutshell
# 86                        Express Entry in a nutshell
# 87                        Express Entry in a nutshell
# 88                        Express Entry in a nutshell
# 89                        Express Entry in a nutshell
# 90  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
# 91  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
# 92  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
# 93  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
# 94  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
# 95  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
# 96  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
# 97  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
# 98  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
# 99  SUMMARY OF ELIGIBILITY REQUIREMENTS FOR ALL EX...
#
# [100 rows x 9 columns]
